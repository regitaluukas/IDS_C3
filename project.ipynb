# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("avalik_2.csv", sep="\t")

# %%
data.head(30)
# Out:
#                                 JuhtumId     ToimKpv ToimKell ToimNadalapaev  \
# 0   d8c560a8-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    23:00      Neljapäev
# 1   f88f8030-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    17:56      Neljapäev
# 2   58f7377a-c36d-18d8-be3c-82234b607189  2020-12-31    17:36      Neljapäev
# 3   d8c56076-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    15:06      Neljapäev
# 4   d8c56062-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    15:02      Neljapäev
# 5   b8a279e0-ce6d-18d8-8408-c1b158cd03d5  2020-12-31    13:28      Neljapäev
# 6   d8c563a0-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    12:33      Neljapäev
# 7   d8c56030-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    12:26      Neljapäev
# 8   d8c56008-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    11:27      Neljapäev
# 9   d8c563b4-b2ec-18d8-809b-f2bfbad78e4c  2020-12-31    03:00      Neljapäev
# 10  d8c55fe0-b2ec-18d8-809b-f2bfbad78e4c  2020-12-30    21:25      Kolmapäev
# ...

# %%
data = data.drop(['JuhtumId','Paragrahv','Loige','SyndmusTaiendavStatLiik','Lest_X','Lest_Y',''], axis=1)

# %%
data.head()
# Out:
#       ToimKpv ToimKell ToimNadalapaev SyndmusLiik             Seadus  \
# 0  2020-12-31    23:00      Neljapäev   VANDALISM  Karistusseadustik
# 1  2020-12-31    17:56      Neljapäev      VARGUS  Karistusseadustik
# 2  2020-12-31    17:36      Neljapäev      VARGUS  Karistusseadustik
# 3  2020-12-31    15:06      Neljapäev  PISIVARGUS  Karistusseadustik
# 4  2020-12-31    15:02      Neljapäev  PISIVARGUS  Karistusseadustik
#
#                                        ParagrahvTais Kahjusumma  \
# 0  § 218. Varavastane süütegu väheväärtusliku asj...   500-4999
# 1                                      § 199. Vargus      0-499
# 2  § 218. Varavastane süütegu väheväärtusliku asj...      0-499
# 3  § 218. Varavastane süütegu väheväärtusliku asj...      0-499
# 4  § 218. Varavastane süütegu väheväärtusliku asj...      0-499
#
#               KohtLiik MaakondNimetus   ValdLinnNimetus  \
# 0          AVALIK_KOHT  Harju maakond  Lääne-Harju vald
# ...
